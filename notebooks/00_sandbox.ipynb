# %%
print("principle-genai-raodmap setup complete")
# Out:
# principle-genai-raodmap setup complete

# %%
print("principle-genai-raodmap setup complete")
# Out:
# principle-genai-raodmap setup complete
